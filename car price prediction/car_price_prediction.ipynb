# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Step 1 : Reading and Understanding the Data

# %%
data = pd.read_csv('CarPrice_Assignment.csv')
data.head(10)
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
# 5       6          2                  audi fox      gas        std        two
# 6       7          1                audi 100ls      gas        std       four
# 7       8          1                 audi 5000      gas        std       four
# 8       9          1                 audi 4000      gas      turbo       four
# 9      10          0       audi 5000s (diesel)      gas      turbo        two
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# ...

# %%
data.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %% [markdown]
# ### Step 2: DATA CLEANING AND PREPARATION

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
data.shape
# Out:
# (205, 26)

# %%
data.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
# columns to keep
# car_ID
# carname
# feultype
# doornumber
# carbody
# drivewheel
# enginetype
# fuelsystem
# horsepower
# peakrpm
# citympg
# highwaympg
# price
newdata=data.copy()
newdata = newdata[['car_ID','fueltype','doornumber','carbody','drivewheel','fuelsystem','horsepower','peakrpm','citympg','highwaympg','price']]
newdata.head()
# Out:
#    car_ID fueltype doornumber      carbody drivewheel fuelsystem  horsepower  \
# 0       1      gas        two  convertible        rwd       mpfi         111
# 1       2      gas        two  convertible        rwd       mpfi         111
# 2       3      gas        two    hatchback        rwd       mpfi         154
# 3       4      gas       four        sedan        fwd       mpfi         102
# 4       5      gas       four        sedan        4wd       mpfi         115
#
#    peakrpm  citympg  highwaympg    price
# 0     5000       21          27  13495.0
# 1     5000       21          27  16500.0
# 2     5000       19          26  16500.0
# 3     5500       24          30  13950.0
# 4     5500       18          22  17450.0

# %% [markdown]
# ### Step3: Data Visualization

# %%
sns.pairplot(newdata)

# %%
plt.figure(figsize=(8,20))
plt.barh(data['CarName'],newdata['price'])
plt.ylabel('Car Name',fontsize='20')
plt.xlabel('Price',fontsize='20')
plt.xticks(rotation=90)
plt.show()

# %%
sorted_data = data.sort_values(by='price', ascending=False)

# Plot the sorted 'price' values
plt.figure(figsize=(20, 8))
plt.bar(data['CarName'], sorted_data['price'])
plt.xlabel('Car Name')
plt.ylabel('Price')
plt.title('Car Prices from Highest to Lowest')
plt.xticks(rotation=90)
plt.show()

# %%
fig=plt.figure(figsize=(15,15))
ax=fig.gca()
newdata.hist(ax=ax)

plt.show()

# %%
newdata.corr
# Out:
# <bound method DataFrame.corr of      car_ID fueltype doornumber      carbody drivewheel fuelsystem  \
# 0         1      gas        two  convertible        rwd       mpfi
# 1         2      gas        two  convertible        rwd       mpfi
# 2         3      gas        two    hatchback        rwd       mpfi
# 3         4      gas       four        sedan        fwd       mpfi
# 4         5      gas       four        sedan        4wd       mpfi
# ..      ...      ...        ...          ...        ...        ...
# 200     201      gas       four        sedan        rwd       mpfi
# 201     202      gas       four        sedan        rwd       mpfi
# 202     203      gas       four        sedan        rwd       mpfi
# 203     204   diesel       four        sedan        rwd        idi
# 204     205      gas       four        sedan        rwd       mpfi
#
#      horsepower  peakrpm  citympg  highwaympg    price
# 0           111     5000       21          27  13495.0
# ...

# %%
colors = np.random.rand(newdata.shape[0])
plt.scatter(newdata['car_ID'],newdata['price'],c=colors,cmap='plasma')
plt.show()

# %%
newdata = newdata[newdata['price'] < 30000]

# %%
newdata.head(5)
# Out:
#    car_ID fueltype doornumber      carbody drivewheel fuelsystem  horsepower  \
# 0       1      gas        two  convertible        rwd       mpfi         111
# 1       2      gas        two  convertible        rwd       mpfi         111
# 2       3      gas        two    hatchback        rwd       mpfi         154
# 3       4      gas       four        sedan        fwd       mpfi         102
# 4       5      gas       four        sedan        4wd       mpfi         115
#
#    peakrpm  citympg  highwaympg    price
# 0     5000       21          27  13495.0
# 1     5000       21          27  16500.0
# 2     5000       19          26  16500.0
# 3     5500       24          30  13950.0
# 4     5500       18          22  17450.0

# %%
newdata['price'].mean()
# Out:
# 11509.400878947368

# %%
colors = np.random.rand(newdata.shape[0])
plt.scatter(newdata['car_ID'],newdata['price'],c=colors,cmap='plasma')
plt.show()

# %%
newdata.head(10)
# Out:
#    car_ID fueltype doornumber      carbody drivewheel fuelsystem  horsepower  \
# 0       1      gas        two  convertible        rwd       mpfi         111
# 1       2      gas        two  convertible        rwd       mpfi         111
# 2       3      gas        two    hatchback        rwd       mpfi         154
# 3       4      gas       four        sedan        fwd       mpfi         102
# 4       5      gas       four        sedan        4wd       mpfi         115
# 5       6      gas        two        sedan        fwd       mpfi         110
# 6       7      gas       four        sedan        fwd       mpfi         110
# 7       8      gas       four        wagon        fwd       mpfi         110
# 8       9      gas       four        sedan        fwd       mpfi         140
# 9      10      gas        two    hatchback        4wd       mpfi         160
#
#    peakrpm  citympg  highwaympg      price
# 0     5000       21          27  13495.000
# ...

# %%
boxdata=newdata[['horsepower','citympg','highwaympg','price']]
colors = ['skyblue', 'lightgreen', 'lightcoral', 'gold']
fig, axes = plt.subplots(1, 4, figsize=(20, 6))

# Create box plots for each column
for i, column in enumerate(boxdata.columns):
    boxdata.boxplot(column, ax=axes[i],color=colors[i],patch_artist=True)
plt.show()

# %%
print(newdata['fueltype'].unique())
print(newdata['doornumber'].unique())
# Out:
# ['gas' 'diesel']
# ['two' 'four']

# %%
newdata['fueltype'] = newdata['fueltype'].map({'gas':0,'diesel':1})
newdata['doornumber']=newdata['doornumber'].map({'two':2,'four':4})
newdata['doornumber']
# Out:
# 0      2
# 1      2
# 2      2
# 3      4
# 4      4
#       ..
# 200    4
# 201    4
# 202    4
# 203    4
# 204    4
# Name: doornumber, Length: 190, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# ### Step4: Converting Data into Numerical Data

# %%
lbl=LabelEncoder()

# %%
encodeddata = newdata.copy()
encodeddata[['carbody','drivewheel','fuelsystem']] = encodeddata[['carbody','drivewheel','fuelsystem']].apply(lambda x:lbl.fit_transform(x))

# %%
encodeddata
# Out:
#      car_ID  fueltype  doornumber  carbody  drivewheel  fuelsystem  \
# 0         1         0           2        0           2           5
# 1         2         0           2        0           2           5
# 2         3         0           2        2           2           5
# 3         4         0           4        3           1           5
# 4         5         0           4        3           0           5
# ..      ...       ...         ...      ...         ...         ...
# 200     201         0           4        3           2           5
# 201     202         0           4        3           2           5
# 202     203         0           4        3           2           5
# 203     204         1           4        3           2           3
# 204     205         0           4        3           2           5
#
#      horsepower  peakrpm  citympg  highwaympg    price
# 0           111     5000       21          27  13495.0
# ...

# %%
corr_matrix = encodeddata.corr()
plt.figure(figsize=(20,8))
sns.heatmap(corr_matrix,annot=True,cmap='plasma')
plt.title('Correlation Heatmap')
plt.show()

# %%
y=encodeddata['price']
x=encodeddata.drop(columns={'price'})

# %% [markdown]
# ### Step5: Training Data

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %% [markdown]
# ### Step6: Linear Regression and Testing

# %%
model.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
predictions=model.predict(xtest)

# %%
predictions
# Out:
# array([ 8557.21856903, 13876.32048778,  6876.75075133,  4638.80550069,
#        18632.84926128,  1580.65945469, 15612.47177873,  5228.90094121,
#         7506.71940253,  8045.45821658,  6911.32854337, 17856.38022546,
#         5306.11814517, 17107.15905576,  7604.32825206, 12901.06600912,
#        15109.83000483,  5996.81982187, 10723.51871739,  6339.35805694,
#         6972.51453638, 11278.49439116, 13132.26423587, 18681.38108997,
#        10770.92457416,  9526.69625672,  6012.45832556,  6664.13246635,
#         6771.66989227, 10716.90151721,  7596.02537478,  5984.6868647 ,
#        13405.12846235, 10713.79668178,  9617.62288345, 16924.93031652,
#         6253.03307235, 10588.01665378])

# %% [markdown]
# ### Metrics For calculating the accuracy

# %%
from sklearn.metrics import r2_score,mean_absolute_error, mean_squared_error
import math

# %%
r2=r2_score(ytest,predictions)
r2=math.ceil(r2*100)

# %%
print('The coefficient of determination is :--> ',r2,'%')
# Out:
# The coefficient of determination is :-->  82 %

# %%
mae = mean_absolute_error(ytest,predictions)
print('The Mean absolute error is :-->',mae)
# Out:
# The Mean absolute error is :--> 1348.9201544574282

# %%
mse = mean_squared_error(ytest,predictions)
print('The mean squared error is :-->',mse)
# Out:
# The mean squared error is :--> 3072385.5190164554

# %%
actual_predicted=pd.DataFrame({'Actual Price':ytest,'Predicted Price':predictions})
actual_predicted.head()
# Out:
#      Actual Price  Predicted Price
# 190        9980.0      8557.218569
# 195       13415.0     13876.320488
# 122        7609.0      6876.750751
# 76         5389.0      4638.805501
# 112       16900.0     18632.849261

# %% [markdown]
# ### Step7: Calculating the difference between the actual and predicted price

# %%
actual_predicted['error'] = actual_predicted['Predicted Price'] - actual_predicted['Actual Price']
actual_predicted.head()
# Out:
#      Actual Price  Predicted Price        error
# 190        9980.0      8557.218569 -1422.781431
# 195       13415.0     13876.320488   461.320488
# 122        7609.0      6876.750751  -732.249249
# 76         5389.0      4638.805501  -750.194499
# 112       16900.0     18632.849261  1732.849261
